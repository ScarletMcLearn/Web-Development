# %% [markdown]
# ####################################################################################################
#
# m_author_f_name = 'Mental Health America'
# Author.f_name = m_author_f_name
# Author.save()
#
#
# m_credit = '© Copyright Mental Health America - 1st of January, 2019'
#
#
# Loop(Start - 0, End - No. of files):
#  		Open Data File:
# 			Article.Title = json.title
# 			Article.source_link = json.source
# 			Article.author = Author.author(MHA)
# 			Article.credit = Credit-Text
# 			Article.save()
#
# 			for itm in json.contents:
# 				TaggedText.tag = itm['tag']
# 				TaggedText.content = itm['content']
# 				TaggedText.article = Article
# 				TaggedText.save()
#
# 		Open Img List File:
# 			if (Img List):
# 				for itm in ImgListFile:
# 					Img.url = ImgListUrl
# 					Img.Article = Article
# 					Img.save()
# 			else:
# 				Img.url = 'www.garbage2343245.com'
# 				Img.Article = Article
# 				Img.save()
#
#
# ##########################################################

# %%
# Creating Author and setting his name

# %%
m_author_f_name = 'Mental Health America'

curr_author = Author()      #uncomment
curr_author.first_name=m_author_f_name      #uncomment


curr_author.save()      #uncomment 

print(m_author_f_name)
# Out:
# Mental Health America

# %%
m_credit = '© Copyright Mental Health America - 1st of January, 2019'

print(m_credit)
# Out:
# © Copyright Mental Health America - 1st of January, 2019

# %%
import json

def open_json(i):
    '''
    Eita Json Return kore
    '''
    with open("/home/scarlet/Projects/Web Development/Back-End/Django/Self Tries/Mental Health/1/AMA Resources/" + str(i)) as complex_data:
         data = complex_data.read()
         data = json.loads(data)
#          data = json.loads(data[0])
         return data

def open_img(i):
    '''
    Eita List Return kore
    '''
    with open("/home/scarlet/Projects/Web Development/Back-End/Django/Self Tries/Mental Health/1/AMA Resources/img" + str(i)) as complex_data:
         data = complex_data.read()
         data = json.loads(data)
         return data

# %%
for i in range(166):
    print('\n\nIteration: ' + str(i))
    c_json_data = open_json(i)
    
    c_article = ArticleInfo()         # uncomment
    c_article.title = c_json_data['title']         # uncomment
    c_article.source = c_json_data['source']         # uncomment
    c_article.author = curr_author         # uncomment
    c_article.credit = m_credit         # uncomment
    c_article.save()         # uncomment
    
    
    c_contents = c_json_data['contents']
    
    
    if c_contents:
        for c in c_contents:
            c_ttxt = TaggedText()         # uncomment
            c_ttxt.content = c['content']         # uncomment
            c_ttxt.c_tag = c['tag']         # uncomment
            c_ttxt.article = c_article         # uncomment
            c_ttxt.save()         # uncomment

            
    img_lst = open_img(i)
    
    if(img_lst):
        for itm in img_lst:
            itm = json.loads(itm)
            
            curr_img_obj = ImgUrl()    # uncomment
            curr_img_obj.url = itm['img']    # uncomment
            curr_img_obj.img_style = itm['style']    # uncomment
            curr_img_obj.article = c_article    # uncomment
            curr_img_obj.save()    # uncomment
# Out:
# Iteration: 0
# 31 Tips to Boost Your Mental Health
# http://www.mentalhealthamerica.net/31-tips-boost-your-mental-health
# style :
# <!--/*--><![CDATA[/* ><!--*/
# .container {
#     position: relative;
#     width: 100%;
#     height: 0;
#     padding-bottom: 60%;
# }
# .video {
#     position: absolute;
#     top: 0;
#     left: 0;
#     width: 100%;
#     height: 100%;
# }
#
# /*--><!]]>*/
#
# ol :
# Track gratitude and achievement with a journal. Include 3 things you were grateful for and 3 things you were able to accomplish each day.
#
# 		Try the free apps – Happier or Attitudes of Gratitude Journal or make your own journal using one of these tutorials.
# Start your day with a cup of co­ffee. Coff­ee consumption is linked to lower rates of depression. If you can’t drink coff­ee because of the caff­eine, try another good-for-you drink like green tea.
#
#
# ...

# %%
for i in range(167):
#     print('\n\nIteration: ' + str(i))
    c_json_data = open_json(i)
    
    if(not c_json_data['title']):
        print('Title not found in file: ' + str(i))
    if(not c_json_data['source']):
        print('Source not found in file: ' + str(i))
    
    
    
    c_contents = c_json_data['contents']
    
    if(not c_contents):
        print('Contents not found in file: ' + str(i))
    
    if c_contents:
        for c in c_contents:
            if(not c['content']):
                print('Tagged text not found in file: ' + str(i))
            if(not c['tag']):
                print('Tags not found in file: ' + str(i))
# Out:
# Contents not found in file: 1
# Tagged text not found in file: 7
# Tagged text not found in file: 10
# Tagged text not found in file: 10
# Tagged text not found in file: 11
# Tagged text not found in file: 18
# Tagged text not found in file: 21
# Tagged text not found in file: 21
# Tagged text not found in file: 21
# Tagged text not found in file: 23
# Tagged text not found in file: 26
# Tagged text not found in file: 28
# Tagged text not found in file: 28
# Tagged text not found in file: 28
# Tagged text not found in file: 28
# Tagged text not found in file: 28
# Tagged text not found in file: 28
# Tagged text not found in file: 28
# Tagged text not found in file: 28
# Tagged text not found in file: 28
# Tagged text not found in file: 28
# Tagged text not found in file: 28
# Tagged text not found in file: 28
# Tagged text not found in file: 29
# Tagged text not found in file: 29
# Tagged text not found in file: 30
# Tagged text not found in file: 31
# ...

# %% [markdown]
# Contents not found in file: 1
# Tagged text not found in file: 7
# Tagged text not found in file: 10
# Tagged text not found in file: 10
# Tagged text not found in file: 11
# Tagged text not found in file: 18
# Tagged text not found in file: 21
# Tagged text not found in file: 21
# Tagged text not found in file: 21
# Tagged text not found in file: 23
# Tagged text not found in file: 26
# Tagged text not found in file: 28
# Tagged text not found in file: 28
# Tagged text not found in file: 28
# Tagged text not found in file: 28
# Tagged text not found in file: 28
# Tagged text not found in file: 28
# Tagged text not found in file: 28
# Tagged text not found in file: 28
# Tagged text not found in file: 28
# Tagged text not found in file: 28
# Tagged text not found in file: 28
# Tagged text not found in file: 28
# Tagged text not found in file: 29
# Tagged text not found in file: 29
# Tagged text not found in file: 30
# Tagged text not found in file: 31
# Tagged text not found in file: 32
# Tagged text not found in file: 33
# Tagged text not found in file: 33
# Tagged text not found in file: 33
